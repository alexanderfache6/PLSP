# %% [markdown]
# # Planet Data API Introduction using Python
#
# ---

# %% [markdown]
# ## Introduction
#
# ---
#
# This tutorial is an introduction to [Planet](https://www.planet.com)'s Data API. It provides code samples on how to write simple Python code to access data.
#
# [`https://api.planet.com/data/v1`](https://api.planet.com/data/v1)
#
# The focus of this tutorial will be the search portion of the Planet Data API. We will find and download imagery data using complex searches and save them for later use, as well as learn how to get stats on search results. After completing this tutorial, you should feel comfortable interacting with the Data API, and have a good foundation for leveraging the Planet Data API for your own applications.

# %% [markdown]
# ## Table of Contents
#
# ---
#
# - **Introduction**
#   - Requirements
#     - Software & Modules
#     - Planet API Key
#   - Useful Links
#
# - **Overview**
#   - The Basic Workflow
#   - Data API Endpoints
#   - Planet Explorer
# - **Basic Setup**
#   - Authentication
#   - Helper Modules and Functions
#   - Our First Request
# - **Search Mechanics & Filters**
#   - Statistics
#   - Using a Search Filter
#   - Filter types
#     - Field Filters
#     - Logical Filters
#     - (Field) Filter Type examples
#   - Complex Queries using Logical Filters
# - **Searching for Items**
#   - Quick Search
#     - Mapping Footprints Example
# - **Assets & Permissions**
#   - Activating Assets
#   - Downloading Assets
#   - Rate Limits
# - **Saved Searches**
#
# - **Conclusion**

# %% [markdown]
# ### Requirements
#
# ---
#
# #### Software & Modules
#
# This tutorial assumes familiarity with the [Python](https://python.org) programming language throughout. Familiarity with basic REST API concepts and usage is also assumed.
#
# We'll be using a **"Jupyter Notebook"** (aka Python Notebook) to run through the examples.
# To learn more about and get started with using Jupyter, visit: [Jupyter](https://jupyter.org/) and [IPython](https://ipython.org/).
#
# For the best experience, download this notebook and run it on your system, and make sure to install the modules listed below first. You can also copy the examples' code to a separate Python files an run them directly with Python on your system if you prefer.
#
# Python modules used in this tutorial are:
#
# - [requests](http://docs.python-requests.org/)
# - [geojsonio](https://pypi.python.org/pypi/geojsonio)
#
# #### Planet API Key
#
# You should have an account on the Planet Platform to access the Data API. You may retrieve your API key from your [account page](https://www.planet.com/account/), or from the "API Tab" in [Planet Explorer](https://www.planet.com/explorer).

# %% [markdown]
# ### Useful links
#
# ---
#
# - [Planet Data API Reference & Documentation](https://developers.planet.com/docs/apis/data/)
# - [Planet Explorer](https://www.planet.com/explorer)

# %% [markdown]
# ## Overview
#
# ---
#
# ### The Basic Workflow:
#
# 1. Search item types based on filters
# 1. Activate assets
# 1. Download assets

# %% [markdown]
# ### API Endpoints
#
# This tutorial will cover the following API **_endpoints_**:
#
# - [`/item-types`](https://api.planet.com/data/v1/item-types/)
# - [`/asset-types`](https://api.planet.com/data/v1/asset-types/)
# - `/quick-search`
# - `/searches`
# - `/stats`
#
# There is an additional [`/spec`](https://api.planet.com/data/v1/spec) endpoint that publishes a [Swagger](http://swagger.io/) specification for the Data API.
#
# ### Exploring Endpoints
#
# We can start by exploring two endpoints using our browser.
#
# ##### What item types are available?
#
# https://api.planet.com/data/v1/item-types/
#
# ##### What assets are available?
#
# https://api.planet.com/data/v1/asset-types/

# %% [markdown]
# **_Note:_** _You may choose to install a helpful browser plugin called **JSONView** that formats JSON and makes it easier to read:_
#
# - [Chrome Extension](https://chrome.google.com/webstore/detail/jsonview/chklaanhfefbnpoihckbnefhakgolnmc)
# - [Firefox Plugin](https://addons.mozilla.org/en-us/firefox/addon/jsonview/)

# %% [markdown]
# ### Planet Explorer
#
# We can also use Planet Explorer to expose relevant API information for search results.
#
# In Planet Explorer, while in _Daily Imagery Mode_ click on the _"Api"_ button in the bottom left corner of the results panel.
#
# ![Planet Explorer Screenshot](images/planet-explorer.png)
#
# Here, you may access your API Key, selected item id's, and `cURL` request information containing filters and options.

# %% [markdown]
# ## Basic Setup
#
# ---
#
# Before interacting with the Planet Data API using Python, we will set up our environment with some useful modules and helper functions.
#
# - We'll configure _authentication_ to the Planet Data API
# - We'll use the `requests` Python module to make HTTP communication easier.
# - We'll use the `json` Python module to help us work with JSON responses from the API.
# - We'll create a function called `p` that will print Python dictionaries nicely.
#
# Then we'll be ready to make our first call to the Planet API by hitting the base endpoint at `https://api.planet.com/data/v1`.
#
# Let's start by importing needed packages configuring authentication:

# %% [markdown]
# ### Import Packages & Define Helper Functions

# %%
import os
import json
import requests
import geojsonio
import time

# Helper function to printformatted JSON using the json module
def p(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# ### Authentication
#
# Authentication with the Planet Data API be achieved using a valid Planet **API key**.

# %% [markdown]
# You can _export_ your API Key as an environment variable on your system:
#
# `export API_KEY="YOUR API KEY HERE"`
#
# Or add the variable to your path, etc. If you are using our Docker environement, it will already be set.
#
# To start our Python code, we'll setup an API Key variable from an environment variable to use with our requests:

# %%
# if your Planet API Key is not set as an environment variable, you can paste it below
if os.environ.get('PL_API_KEY', ''):
    API_KEY = os.environ.get('PL_API_KEY', '')
else:
    API_KEY = 'PASTE_YOUR_API_KEY_HERE'

    # construct auth tuple for use in the requests library
BASIC_AUTH = (API_KEY, '')

# %% [markdown]
# ### Our First Request

# %%
# Setup Planet Data API base URL
URL = "https://api.planet.com/data/v1"

# Setup the session
session = requests.Session()

# Authenticate
session.auth = (API_KEY, "")

# %%
# Make a GET request to the Planet Data API
res = session.get(URL)

# %% [markdown]
# Now we should get a response, hopefully it's a `200` code, saying everything is OK!

# %%
# Response status code
res.status_code
# Out:
# 200

# %%
# Response Body
res.text
# Out:
# '{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
# Print formatted JSON response
p(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec"
#   }
# }

# %%
# Print the value of the item-types key from _links
print(res.json()["_links"]["item-types"])
# Out:
# https://api.planet.com/data/v1/item-types/

# %% [markdown]
# **Congratulations!** You just made your first request to the Planet Data API using Python!
#
# Now, let's take a look at how to access all that high cadence satellite imagery!

# %% [markdown]
# ## Search Mechanics & Filters
#
# ---
#
# There's a lot of data available on the Planet Data API and in order to find what we're looking for, we'll have to perform various types of searches.
#
# To construct a search, we use **filters** that let us limit results based on date, geography or other metadata properties.
#
# Using these filters, we are able to **search** for items or get **statistics** for search results.
#
# Let's first make a request to the `/stats` endpoint to understand how the filters work:

# %% [markdown]
# ### Statistics `/stats`
#
# ---
#
# The `/stats` endpoint provides a summary of the available data based on some search criteria.
#
# `https://api.planet.com/data/v1/stats`
#
# We'll need to send a **_`POST`_** request to `/stats`, let's start by setting up the request url:

# %%
# Setup the stats URL
stats_url = "{}/stats".format(URL)

# Print the stats URL
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %% [markdown]
# ### Using a Search Filter
#
# Search filters should have the following properties:
#
# - **Type** (`type`) - The type of filter being used
# - **Configuration** (`config`) - The configuration for this filter
# - **Field Name** (`field_name`) - The field on which to filter
#
# For this example, let's use a filter to get some stats on what data is available for _Planet Scope (3 Band)_ and _Rapid Eye (Ortho Tile)_ products taken from 2013 until now:

# %%
# Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene", "REOrthoTile"]

# %%
# Create filter object for all imagery captured between 2013-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %% [markdown]
# Depending on the filter type, some requests may need an `interval` field:
#
# The following intervals are possible:
#
# - `year`
# - `month`
# - `week`
# - `day`
# - `hour`
#
# An `interval` must be provided with the request so that the number of matching items can be aggregated. We'll use an interval with our date filter.

# %% [markdown]
# Now let's perform our request using the `date_filter` filter we created above:

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "message": "Please provide valid credentials. See https://docs.planet.com/develop/authentication for help.",
#   "errors": []
# }

# %% [markdown]
# **_Good Job!_** You've received a response from the API that contains some statistics like item counts for the search criteria!

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new date filter to find data from before 2013.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 
date_filter2 = {
    "type": "DateRangeFilter",
    "field_name": "acquired",
    "config": {
        "lte": "2013-01-01T00:00:00.000Z",
    }
}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter2
}

res = session.post(stats_url, json=request)
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 1353609,
#       "start_time": "2009-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 2153888,
#       "start_time": "2010-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 2493280,
#       "start_time": "2011-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 2716480,
#       "start_time": "2012-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# ---
#
# Next, let's take a closer look at some of the available filters:

# %% [markdown]
# ### Filter types
#
# The Planet Data API supports several filter types. The most common are the following:
#
# ### Field Filters
#
# - `DateRangeFilter`
# - `RangeFilter`
# - `StringInFilter`
# - `PermissionFilter`
# - `GeometryFilter`
#
# ### Logical Filters
#
# - `NotFilter`
# - `AndFilter`
# - `OrFilter`
#
# More information and examples on filter types can be found at the [API Docs](https://developers.planet.com/docs/apis/).
#
# ---
#
# ### (Field) Filter Type examples:

# %% [markdown]
# #### `DateRangeFilter`
#
# Find imagery that was `acquired` or `published` before, after or between certain dates.
#
# ```
# {
#   "type": "DateRangeFilter",
#   "field_name": "acquired",
#   "config": {
#     "gt": "2016-01-01T00:00:00Z",
#     "lte": "2016-03-01T00:00:00Z"
#   }
# }
# ```
#
# The upper or lower bound may be omitted.

# %% [markdown]
# #### `RangeFilter`
#
# Find imagery that has a metadata that matches a number within a range of numbers.
#
# ```
# {
#   "type": "RangeFilter",
#   "field_name": "cloud_cover",
#   "config": {
#     "lt": 0.2,
#     "gt": 0.1
#   }
# }
# ```

# %% [markdown]
# The following **operators** are supported by the Data API's `DateRangeFilter` and `RangeFilter`:
#
# - `gt`: Greater Than
# - `gte`: Greater Than or Equal To
# - `lt`: Less Than
# - `lte`: Less Than or Equal To

# %% [markdown]
# #### `StringInFilter`
#
# Find imagery that has a metadata that matches a string within the array of provided strings.
#
# ```
# {
#   "type": "StringInFilter",
#   "field_name": "instrument",
#   "config": ["PS2"]
# }
# ```

# %% [markdown]
# #### `PermissionFilter`
#
# Find data which has assets that are accessible by the user.
#
# ```
# {
#   "type": "PermissionFilter",
#   "config": ["assets.analytic:download"]
# }
# ```
#
# **_Note:_** `assets:download` means _any_ downloadable asset.

# %% [markdown]
# #### `GeometryFilter`
#
# Find data contained within a given geometry. The filter's config value may be any valid GeoJSON object.
#
# ```
# {
#   "type": "GeometryFilter",
#   "field_name": "geometry",
#   "config": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ]
#       ]
#     ]
#   }
# }
# ```
#
# A few quick ways to get a GeoJSON geometry to use in your search:
#
# - Draw an Area of Interst (AOI) in [Planet Explorer](http://planet.com/explorer), and use the API button to see the geometry filter config.
# - Use your favorite GIS tools like [Quantum GIS (QGIS)](http://www.qgis.org) and export GeoJSON.
# - Draw a polygon in [GeoJSON.io](http://geojson.io).
#
# Make sure the `config` property in the geometry filter is in the right format, which should be similar to a `feature` property in a GeoJSON object.

# %% [markdown]
# ---
#
# Let's try a few more requests and get some more stats, this time using different filters:

# %%
# Search for imagery only from PlanetScope satellites that have a PS2 telescope

# Setup item types
item_types = ["PSScene"]

# Setup a filter for instrument type
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 1551072,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 34389618,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 213006138,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 286273822,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 212799869,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 192136034,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 137381693,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 22968748,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new filter that finds all data from PS0 or PS1 telescopes.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 

instrument_filter2 = {
}
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter2
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.type": [
#       {
#         "message": "'type' is a required property"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# Find a GeoJSON geometry from http://geojson.io and copy one `feature`.

# %%
# Search for imagery that only intersects with 40N, 90W

# Setup GeoJSON 
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup Geometry Filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : geometry_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 6,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 4,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 46,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 176,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 302,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 352,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 393,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 506,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 374,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 423,
#       "start_time": "2023-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 536,
#       "start_time": "2024-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 525,
#       "start_time": "2025-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 243,
#       "start_time": "2026-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# ### Complex Queries using Logical Filters
#
# Complex queries may require combining field filters using **logical filters** (see Filter Types above).
#
# Let's try a complex stats search:

# %%
# PS2 imagery; over 40N, 90W; captured between 2013 and present

# Setup an "AND" logical filter
and_filter = {
    "type": "AndFilter",
    "config": [instrument_filter, geometry_filter, date_filter]
}

# Print the logical filter
p(and_filter)
# Out:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "type": "StringInFilter",
#       "field_name": "instrument",
#       "config": [
#         "PS2"
#       ]
#     },
#     {
#       "type": "GeometryFilter",
#       "field_name": "geometry",
#       "config": {
#         "type": "Point",
#         "coordinates": [
#           -90,
#           40
#         ]
#       }
#     },
#     {
#       "type": "DateRangeFilter",
#       "field_name": "acquired",
#       "config": {
#         "gte": "2013-01-01T00:00:00.000Z"
#       }
#     }
#   ]
# }

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : and_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 1,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 45,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 176,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 302,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 253,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 204,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 147,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 25,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Here's another complex search query example using a "Not" logical filter and "string in" field filter. Can you tell what it's requesting?

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup Instrument Filter
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# Setup "not" Logical Filter
not_filter = {
    "type": "NotFilter",
    "config": instrument_filter
}

# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : not_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 466239,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3602217,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3872489,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 833,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 0,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 27134723,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 43905139,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 81622384,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 99917183,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 115831581,
#       "start_time": "2023-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 125407427,
#       "start_time": "2024-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 100701582,
#       "start_time": "2025-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 49245755,
#       "start_time": "2026-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Now that you're comfortable working with **filters**, let's take a look at how to perform searches!

# %% [markdown]
# ## Searching for Items
#
# ---
#
# There are two types of searches:
#
# - **"Quick Search"** `/quick-search`
# - **"Saved Searches"** `/searches`
#
# Saved searches are retained on the Planet Platform and may be performed again at any time in the future. You can use these to setup efficient workflows for repetitive tasks, for example, querying an area that is of interest to you, or getting data for specific sensors.
#
# Quick searches are meant to be more fleeting, and are not guaranteed to be available on the API after they are executed.
#
# Searches use the same request format as the `/stats` endpoint except without the `interval` field.

# %% [markdown]
# ### Quick Search
#
# Let's dive right in and create our first `quick search`:

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
quick_url
# Out:
# 'https://api.planet.com/data/v1/quick-search'

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup GeoJSON for only imagery that intersects with 40N, 90W
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup a geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/8cda9d75b89d41f5a7e6a0102c027504/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/8cda9d75b89d41f5a7e6a0102c027504/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDI2LTAxLTAxVDE4OjI4OjUxLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjUxMjI2XzE3MzkzOF8xM18yNGUxIiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/8cda9d75b89d41f5a7e6a0102c027504/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260614_172350_14_253b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260614_172350_14_253b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260614_172350_14_253b/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.23479770958222,
#               40.1643688762638
#             ],
#             [
#               -90.2843053252,
#               39.991366905856296
#             ],
#             [
#               -89.90815425667407,
#               39.92671868452805
#             ],
#             [
#               -89.85721810180573,
#               40.099745232978066
#             ],
#             [
#               -90.23479770958222,
#               40.1643688762638
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260614_172350_14_253b",
#       "properties": {
#         "acquired": "2026-06-14T17:23:50.144989Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 82,
#         "clear_percent": 36,
#         "cloud_cover": 0.53,
#         "cloud_percent": 53,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 4,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-14T23:19:55Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 271.4,
#         "satellite_id": "253b",
#         "shadow_percent": 7,
#         "snow_ice_percent": 0,
#         "strip_id": "8847336",
#         "sun_azimuth": 152.1,
#         "sun_elevation": 71.5,
#         "updated": "2026-06-15T11:16:57Z",
#         "view_angle": 1,
#         "visible_confidence_percent": 64,
#         "visible_percent": 47
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260613_164910_38_2544",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260613_164910_38_2544/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260613_164910_38_2544/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -89.99108688369496,
#               40.09674152578379
#             ],
#             [
#               -90.04248874071097,
#               39.91312687429902
#             ],
#             [
#               -89.64346436915825,
#               39.84450834048313
#             ],
#             [
#               -89.59098922955528,
#               40.02781689956208
#             ],
#             [
#               -89.99108688369496,
#               40.09674152578379
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260613_164910_38_2544",
#       "properties": {
#         "acquired": "2026-06-13T16:49:10.385823Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 76,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-13T22:05:54Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 120.9,
#         "satellite_id": "2544",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8845234",
#         "sun_azimuth": 133.3,
#         "sun_elevation": 67.7,
#         "updated": "2026-06-14T04:06:44Z",
#         "view_angle": 0.5,
#         "visible_confidence_percent": 50,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260613_165121_65_256e",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260613_165121_65_256e/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260613_165121_65_256e/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.14985267885719,
#               40.14836552969042
#             ],
#             [
#               -90.20223708136267,
#               39.9667583493315
#             ],
#             [
#               -89.8079913747948,
#               39.89956256966068
#             ],
#             [
#               -89.75442538681462,
#               40.081214406409046
#             ],
#             [
#               -90.14985267885719,
#               40.14836552969042
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260613_165121_65_256e",
#       "properties": {
#         "acquired": "2026-06-13T16:51:21.656859Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 77,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-13T20:45:48Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 269.3,
#         "satellite_id": "256e",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8845074",
#         "sun_azimuth": 133.8,
#         "sun_elevation": 67.8,
#         "updated": "2026-06-14T05:34:07Z",
#         "view_angle": 1.1,
#         "visible_confidence_percent": 50,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260612_164750_05_2510",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260612_164750_05_2510/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260612_164750_05_2510/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.00986287084149,
#               40.116363865181285
#             ],
#             [
#               -90.0613293951139,
#               39.93254599659511
#             ],
#             [
#               -89.6622658973535,
#               39.865990383424034
#             ],
#             [
#               -89.60974663805658,
#               40.048634717528174
#             ],
#             [
#               -90.00986287084149,
#               40.116363865181285
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260612_164750_05_2510",
#       "properties": {
#         "acquired": "2026-06-12T16:47:50.052278Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 99,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-12T20:33:32Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 102.2,
#         "satellite_id": "2510",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8843079",
#         "sun_azimuth": 133.3,
#         "sun_elevation": 67.7,
#         "updated": "2026-06-13T03:59:57Z",
#         "view_angle": 3.2,
#         "visible_confidence_percent": 69,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260612_172513_60_2527",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260612_172513_60_2527/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260612_172513_60_2527/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.18523064883871,
#               40.158644580278
#             ],
#             [
#               -90.23566827523317,
#               39.98630327072391
#             ],
#             [
#               -89.85958312276236,
#               39.92032452965334
#             ],
#             [
#               -89.80780266981357,
#               40.09319729575677
#             ],
#             [
#               -90.18523064883871,
#               40.158644580278
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260612_172513_60_2527",
#       "properties": {
#         "acquired": "2026-06-12T17:25:13.605798Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 98,
#         "clear_percent": 99,
#         "cloud_cover": 0.01,
#         "cloud_percent": 1,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-12T19:46:39Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.2,
#         "satellite_id": "2527",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8843041",
#         "sun_azimuth": 153,
#         "sun_elevation": 71.5,
#         "updated": "2026-06-13T05:33:51Z",
#         "view_angle": 3.4,
#         "visible_confidence_percent": 68,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260611_172541_49_2526",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260611_172541_49_2526/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260611_172541_49_2526/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.18919332113599,
#               40.087658695307354
#             ],
#             [
#               -90.23849186471278,
#               39.91623614902235
#             ],
#             [
#               -89.86088278894158,
#               39.850569352378244
#             ],
#             [
#               -89.81020286676973,
#               40.022927721947354
#             ],
#             [
#               -90.18919332113599,
#               40.087658695307354
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260611_172541_49_2526",
#       "properties": {
#         "acquired": "2026-06-11T17:25:41.499401Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 99,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-12T04:31:10Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 278.1,
#         "satellite_id": "2526",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8841598",
#         "sun_azimuth": 153,
#         "sun_elevation": 71.5,
#         "updated": "2026-06-12T08:18:27Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 50,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260610_164757_13_24d8",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260610_164757_13_24d8/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260610_164757_13_24d8/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.20785638413196,
#               40.074587196613955
#             ],
#             [
#               -90.25851609134357,
#               39.89042162993088
#             ],
#             [
#               -89.85797303029683,
#               39.82518712175118
#             ],
#             [
#               -89.80667887847062,
#               40.007851007483445
#             ],
#             [
#               -90.20785638413196,
#               40.074587196613955
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260610_164757_13_24d8",
#       "properties": {
#         "acquired": "2026-06-10T16:47:57.132777Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 83,
#         "clear_percent": 66,
#         "cloud_cover": 0.05,
#         "cloud_percent": 5,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 29,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-10T20:26:24Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 101.4,
#         "satellite_id": "24d8",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "8838943",
#         "sun_azimuth": 133.7,
#         "sun_elevation": 67.7,
#         "updated": "2026-06-11T03:57:58Z",
#         "view_angle": 5.1,
#         "visible_confidence_percent": 71,
#         "visible_percent": 95
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260609_172512_09_252a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260609_172512_09_252a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260609_172512_09_252a/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -89.98540287432536,
#               40.15583721915059
#             ],
#             [
#               -90.03433292916397,
#               39.98525441836702
#             ],
#             [
#               -89.66280133910561,
#               39.92127920127978
#             ],
#             [
#               -89.61256262599503,
#               40.0922232547665
#             ],
#             [
#               -89.98540287432536,
#               40.15583721915059
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260609_172512_09_252a",
#       "properties": {
#         "acquired": "2026-06-09T17:25:12.096152Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 75,
#         "clear_percent": 67,
#         "cloud_cover": 0.19,
#         "cloud_percent": 19,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 12,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-10T05:16:16Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 274.7,
#         "satellite_id": "252a",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "8837154",
#         "sun_azimuth": 154.5,
#         "sun_elevation": 71.5,
#         "updated": "2026-06-10T13:01:25Z",
#         "view_angle": 2.1,
#         "visible_confidence_percent": 62,
#         "visible_percent": 81
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260609_172514_10_252a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260609_172514_10_252a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260609_172514_10_252a/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.0219450670336,
#               40.02939615039696
#             ],
#             [
#               -90.07076094967975,
#               39.85885250660183
#             ],
#             [
#               -89.6998946416464,
#               39.79493670249028
#             ],
#             [
#               -89.64986106932344,
#               39.96585086131202
#             ],
#             [
#               -90.0219450670336,
#               40.02939615039696
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260609_172514_10_252a",
#       "properties": {
#         "acquired": "2026-06-09T17:25:14.100793Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 80,
#         "clear_percent": 87,
#         "cloud_cover": 0.07,
#         "cloud_percent": 7,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 5,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-10T05:15:24Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 274.7,
#         "satellite_id": "252a",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "8837154",
#         "sun_azimuth": 154.3,
#         "sun_elevation": 71.6,
#         "updated": "2026-06-10T13:01:25Z",
#         "view_angle": 2.1,
#         "visible_confidence_percent": 64,
#         "visible_percent": 93
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260608_164951_05_256c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260608_164951_05_256c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260608_164951_05_256c/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.16652874963032,
#               40.121417349059904
#             ],
#             [
#               -90.21881988113518,
#               39.93912542007777
#             ],
#             [
#               -89.82297907178472,
#               39.8719378431395
#             ],
#             [
#               -89.77018920362481,
#               40.05385615062747
#             ],
#             [
#               -90.16652874963032,
#               40.121417349059904
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260608_164951_05_256c",
#       "properties": {
#         "acquired": "2026-06-08T16:49:51.057686Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 58,
#         "clear_percent": 0,
#         "cloud_cover": 0.85,
#         "cloud_percent": 85,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 14,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-09T04:45:13Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 268.6,
#         "satellite_id": "256c",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8835733",
#         "sun_azimuth": 134.1,
#         "sun_elevation": 67.5,
#         "updated": "2026-06-11T06:57:30Z",
#         "view_angle": 0.9,
#         "visible_confidence_percent": 73,
#         "visible_percent": 15
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260409_165009_53_2550",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260409_165009_53_2550/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260409_165009_53_2550/thumb"
#       },
#       "_permissions": [
#         "assets.ortho_visual:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_udm2:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.ortho_analytic_8b_sr:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.09462525573208,
#               40.13747853924116
#             ],
#             [
#               -90.14591242539616,
#               39.95356674854423
#             ],
#             [
#               -89.74650142153989,
#               39.88688438071967
#             ],
#             [
#               -89.69398600561176,
#               40.07049240878861
#             ],
#             [
#               -90.09462525573208,
#               40.13747853924116
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260409_165009_53_2550",
#       "properties": {
#         "acquired": "2026-04-09T16:50:09.539513Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 95,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-08T23:57:23Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 150.2,
#         "satellite_id": "2550",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8714277",
#         "sun_azimuth": 149.1,
#         "sun_elevation": 54,
#         "updated": "2026-06-08T23:57:23Z",
#         "view_angle": 0.7,
#         "visible_confidence_percent": 74,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20251218_165238_00_2550",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20251218_165238_00_2550/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20251218_165238_00_2550/thumb"
#       },
#       "_permissions": [
#         "assets.ortho_visual:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_udm2:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.ortho_analytic_8b_sr:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.26885727853922,
#               40.08858104498143
#             ],
#             [
#               -90.32148643127205,
#               39.90635141258742
#             ],
#             [
#               -89.92005739913893,
#               39.83781586934436
#             ],
#             [
#               -89.86631421316977,
#               40.01982838613249
#             ],
#             [
#               -90.26885727853922,
#               40.08858104498143
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20251218_165238_00_2550",
#       "properties": {
#         "acquired": "2025-12-18T16:52:38.007953Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 60,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-08T18:16:34Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 185.2,
#         "satellite_id": "2550",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8476506",
#         "sun_azimuth": 163.6,
#         "sun_elevation": 24.9,
#         "updated": "2026-06-08T18:16:34Z",
#         "view_angle": 0.3,
#         "visible_confidence_percent": 50,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260607_165216_63_2575",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260607_165216_63_2575/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260607_165216_63_2575/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.29749207773551,
#               40.177066702445586
#             ],
#             [
#               -90.35059199969268,
#               39.99527645481735
#             ],
#             [
#               -89.95295274670771,
#               39.925743159607876
#             ],
#             [
#               -89.89833201190602,
#               40.10815598850369
#             ],
#             [
#               -90.29749207773551,
#               40.177066702445586
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260607_165216_63_2575",
#       "properties": {
#         "acquired": "2026-06-07T16:52:16.632098Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 85,
#         "clear_percent": 0,
#         "cloud_cover": 0.79,
#         "cloud_percent": 79,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 21,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-07T20:42:35Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 278,
#         "satellite_id": "2575",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8832651",
#         "sun_azimuth": 134.6,
#         "sun_elevation": 67.4,
#         "updated": "2026-06-08T03:57:46Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 83,
#         "visible_percent": 21
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260606_172354_27_2534",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260606_172354_27_2534/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260606_172354_27_2534/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.15629242554049,
#               40.20794234976799
#             ],
#             [
#               -90.20626913696324,
#               40.035061919260556
#             ],
#             [
#               -89.82916307603733,
#               39.969734564841055
#             ],
#             [
#               -89.77796849114362,
#               40.14316689162235
#             ],
#             [
#               -90.15629242554049,
#               40.20794234976799
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260606_172354_27_2534",
#       "properties": {
#         "acquired": "2026-06-06T17:23:54.278152Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 68,
#         "clear_percent": 12,
#         "cloud_cover": 0.67,
#         "cloud_percent": 67,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 19,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-07T01:44:38Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 276.4,
#         "satellite_id": "2534",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "8831171",
#         "sun_azimuth": 153.9,
#         "sun_elevation": 71,
#         "updated": "2026-06-07T09:57:38Z",
#         "view_angle": 2.3,
#         "visible_confidence_percent": 63,
#         "visible_percent": 33
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260606_172356_50_2534",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260606_172356_50_2534/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260606_172356_50_2534/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.19660419337625,
#               40.06806464440886
#             ],
#             [
#               -90.2462896252043,
#               39.895202825308985
#             ],
#             [
#               -89.87006593567635,
#               39.8300160153116
#             ],
#             [
#               -89.81891517798582,
#               40.00335852963414
#             ],
#             [
#               -90.19660419337625,
#               40.06806464440886
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260606_172356_50_2534",
#       "properties": {
#         "acquired": "2026-06-06T17:23:56.508678Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 65,
#         "clear_percent": 15,
#         "cloud_cover": 0.59,
#         "cloud_percent": 59,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 23,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-07T01:43:42Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 276.2,
#         "satellite_id": "2534",
#         "shadow_percent": 3,
#         "snow_ice_percent": 0,
#         "strip_id": "8831171",
#         "sun_azimuth": 153.6,
#         "sun_elevation": 71.2,
#         "updated": "2026-06-07T07:59:38Z",
#         "view_angle": 2.3,
#         "visible_confidence_percent": 62,
#         "visible_percent": 41
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260605_172315_95_2530",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260605_172315_95_2530/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260605_172315_95_2530/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.19057069148273,
#               40.09828068860505
#             ],
#             [
#               -90.23810569387544,
#               39.932630384626485
#             ],
#             [
#               -89.8602799132119,
#               39.87123668098229
#             ],
#             [
#               -89.81100283334919,
#               40.037919296851825
#             ],
#             [
#               -90.19057069148273,
#               40.09828068860505
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260605_172315_95_2530",
#       "properties": {
#         "acquired": "2026-06-05T17:23:15.952311Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 58,
#         "clear_percent": 0,
#         "cloud_cover": 0.93,
#         "cloud_percent": 93,
#         "ground_control": false,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 7,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-06T00:54:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 278.3,
#         "satellite_id": "2530",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8829047",
#         "sun_azimuth": 152.8,
#         "sun_elevation": 70.9,
#         "updated": "2026-06-06T09:58:45Z",
#         "view_angle": 5.3,
#         "visible_confidence_percent": 71,
#         "visible_percent": 7
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260605_165211_39_254c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260605_165211_39_254c/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260605_165211_39_254c/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.03745289484829,
#               40.10265439978057
#             ],
#             [
#               -90.09140557278084,
#               39.91844256748387
#             ],
#             [
#               -89.69214131323571,
#               39.84808550968702
#             ],
#             [
#               -89.63670420923314,
#               40.03328725302531
#             ],
#             [
#               -90.03745289484829,
#               40.10265439978057
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260605_165211_39_254c",
#       "properties": {
#         "acquired": "2026-06-05T16:52:11.394378Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 75,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-05T22:25:51Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 277.9,
#         "satellite_id": "254c",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8828686",
#         "sun_azimuth": 135.4,
#         "sun_elevation": 67.4,
#         "updated": "2026-06-06T04:11:52Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 69,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260604_172504_00_2526",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260604_172504_00_2526/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260604_172504_00_2526/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.07661981637375,
#               40.184214141375094
#             ],
#             [
#               -90.12639992273854,
#               40.01166729116012
#             ],
#             [
#               -89.74851572974595,
#               39.94630480229512
#             ],
#             [
#               -89.69733483354548,
#               40.11965656978297
#             ],
#             [
#               -90.07661981637375,
#               40.184214141375094
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260604_172504_00_2526",
#       "properties": {
#         "acquired": "2026-06-04T17:25:04.005521Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 73,
#         "clear_percent": 28,
#         "cloud_cover": 0.27,
#         "cloud_percent": 27,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 42,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-06-04T23:20:24Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 278.1,
#         "satellite_id": "2526",
#         "shadow_percent": 2,
#         "snow_ice_percent": 0,
#         "strip_id": "8826648",
#         "sun_azimuth": 154.6,
#         "sun_elevation": 70.9,
#         "updated": "2026-06-05T05:34:56Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 70,
#         "visible_percent": 73
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260604_172506_24_2526",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260604_172506_24_2526/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260604_172506_24_2526/thumb"
#       },
#       "_permissions": [],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.11788812874941,
#               40.04362113989865
#             ],
#             [
#               -90.16745753162442,
#               39.87110629547277
#             ],
#             [
#               -89.79035946256091,
#               39.80583125952959
#             ],
#             [
#               -89.73939844138567,
#               39.97916611275643
#             ],
#             [
#               -90.11788812874941,
#               40.04362113989865
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260604_172506_24_2526",
#       "properties": {
#         "acquired": "2026-06-04T17:25:06.243848Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 67,
#         "clear_percent": 8,
#         "cloud_cover": 0.32,
#         "cloud_percent": 32,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
# ...
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 136.2,
#         "satellite_id": "2579",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8510348",
#         "sun_azimuth": 161.6,
#         "sun_elevation": 25,
#         "updated": "2026-01-13T10:03:21Z",
#         "view_angle": 0.4,
#         "visible_confidence_percent": 61,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260103_165209_70_2579",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260103_165209_70_2579/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260103_165209_70_2579/thumb"
#       },
#       "_permissions": [
#         "assets.ortho_visual:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_udm2:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.ortho_analytic_8b_sr:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.20292648839296,
#               40.06047845494296
#             ],
#             [
#               -90.25530367580524,
#               39.8777467848149
#             ],
#             [
#               -89.85919189260068,
#               39.80946568674538
#             ],
#             [
#               -89.80531198309896,
#               39.99172711270982
#             ],
#             [
#               -90.20292648839296,
#               40.06047845494296
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260103_165209_70_2579",
#       "properties": {
#         "acquired": "2026-01-03T16:52:09.708863Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 88,
#         "clear_percent": 99,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 1,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-01-03T20:32:26Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 136.6,
#         "satellite_id": "2579",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8510348",
#         "sun_azimuth": 161.6,
#         "sun_elevation": 25.1,
#         "updated": "2026-01-14T12:55:26Z",
#         "view_angle": 0.4,
#         "visible_confidence_percent": 68,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260102_172035_64_253b",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260102_172035_64_253b/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260102_172035_64_253b/thumb"
#       },
#       "_permissions": [
#         "assets.ortho_visual:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_udm2:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.ortho_analytic_8b_sr:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.21022882134295,
#               40.142259336087
#             ],
#             [
#               -90.25578043485551,
#               39.95430309613504
#             ],
#             [
#               -89.8717995250674,
#               39.88650767701793
#             ],
#             [
#               -89.8248409696771,
#               40.07546144353957
#             ],
#             [
#               -90.21022882134295,
#               40.142259336087
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260102_172035_64_253b",
#       "properties": {
#         "acquired": "2026-01-02T17:20:35.648923Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 76,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-01-02T22:40:47Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 278.1,
#         "satellite_id": "253b",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8508553",
#         "sun_azimuth": 168.3,
#         "sun_elevation": 26.1,
#         "updated": "2026-01-03T04:33:05Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 49,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260101_171719_87_24db",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260101_171719_87_24db/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260101_171719_87_24db/thumb"
#       },
#       "_permissions": [
#         "assets.ortho_visual:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_udm2:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.ortho_analytic_8b_sr:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.21548379621892,
#               40.16689148303721
#             ],
#             [
#               -90.26168476757123,
#               40.00185540200167
#             ],
#             [
#               -89.90289431623499,
#               39.94221283113673
#             ],
#             [
#               -89.85602429053738,
#               40.106540390004476
#             ],
#             [
#               -90.21548379621892,
#               40.16689148303721
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20260101_171719_87_24db",
#       "properties": {
#         "acquired": "2026-01-01T17:17:19.877968Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 75,
#         "clear_percent": 33,
#         "cloud_cover": 0.13,
#         "cloud_percent": 13,
#         "ground_control": true,
#         "gsd": 3.5,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 53,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-01-01T20:56:22Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 103.4,
#         "satellite_id": "24db",
#         "shadow_percent": 1,
#         "snow_ice_percent": 0,
#         "strip_id": "8506315",
#         "sun_azimuth": 168.3,
#         "sun_elevation": 26.1,
#         "updated": "2026-01-02T04:49:12Z",
#         "view_angle": 2.3,
#         "visible_confidence_percent": 63,
#         "visible_percent": 87
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20251226_173939_87_24e1",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20251226_173939_87_24e1/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20251226_173939_87_24e1/thumb"
#       },
#       "_permissions": [
#         "assets.ortho_visual:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_udm2:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.ortho_analytic_8b_sr:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.27884335787716,
#               40.04854131462423
#             ],
#             [
#               -90.32301724001422,
#               39.8978208538116
#             ],
#             [
#               -89.993166002705,
#               39.83985693925004
#             ],
#             [
#               -89.94790100924932,
#               39.99139194821124
#             ],
#             [
#               -90.27884335787716,
#               40.04854131462423
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20251226_173939_87_24e1",
#       "properties": {
#         "acquired": "2025-12-26T17:39:39.875977Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 63,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.3,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-01-01T18:29:25Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 278.2,
#         "satellite_id": "24e1",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8504233",
#         "sun_azimuth": 174,
#         "sun_elevation": 26.4,
#         "updated": "2026-01-01T18:29:25Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 54,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20251226_173938_13_24e1",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20251226_173938_13_24e1/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20251226_173938_13_24e1/thumb"
#       },
#       "_permissions": [
#         "assets.ortho_visual:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_udm2:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.ortho_analytic_8b_sr:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.24662983437105,
#               40.15947185449062
#             ],
#             [
#               -90.29091392098073,
#               40.008755134298625
#             ],
#             [
#               -89.96050106999596,
#               39.95074960924545
#             ],
#             [
#               -89.91512141002264,
#               40.10228407258724
#             ],
#             [
#               -90.24662983437105,
#               40.15947185449062
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20251226_173938_13_24e1",
#       "properties": {
#         "acquired": "2025-12-26T17:39:38.137405Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 62,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.3,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2026-01-01T18:28:51Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 278.1,
#         "satellite_id": "24e1",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "8504233",
#         "sun_azimuth": 174.1,
#         "sun_elevation": 26.3,
#         "updated": "2026-01-01T18:28:51Z",
#         "view_angle": 4.9,
#         "visible_confidence_percent": 53,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Nice! The response gives us search results for Planet Scope (4 Band) for a specific area.
#
# Let's do another search, this time using the "not" filter we setup earlier:

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : not_filter
}

# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(list(geojson.items())[1][1][0])
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260616_172548_62_2528",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260616_172548_62_2528/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260616_172548_62_2528/thumb"
#   },
#   "_permissions": [],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -100.72027837490471,
#           28.25523928838242
#         ],
#         [
#           -100.36410647786613,
#           28.18965011848578
#         ],
#         [
#           -100.40914416955061,
#           28.001627923523706
#         ],
#         [
#           -100.7643073041518,
#           28.06831216362462
#         ],
#         [
#           -100.72027837490471,
#           28.25523928838242
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20260616_172548_62_2528",
#   "properties": {
#     "acquired": "2026-06-16T17:25:48.626019Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 61,
#     "clear_percent": 11,
#     "cloud_cover": 0.65,
#     "cloud_percent": 65,
#     "ground_control": false,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 21,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2026-06-16T21:09:34Z",
#     "publishing_stage": "preview",
#     "quality_category": "test",
#     "satellite_azimuth": 276.8,
#     "satellite_id": "2528",
#     "shadow_percent": 2,
#     "snow_ice_percent": 2,
#     "strip_id": "8850926",
#     "sun_azimuth": 100.7,
#     "sun_elevation": 71.6,
#     "updated": "2026-06-16T21:09:34Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 56,
#     "visible_percent": 35
#   },
#   "type": "Feature"
# }

# %% [markdown]
# Let's take a closer look at our response data:

# %%
# Assign a features variable 
features = geojson["features"]

# Get the number of features present in the response
len(features)
# Out:
# 250

# %%
# Loop over all the features from the response
for f in features:
    # Print the ID for each feature
    p(f["id"])
# Out:
# "20260616_172548_62_2528"
# "20260616_172250_28_2528"
# "20260616_172717_79_2528"
# "20260616_172546_27_2528"
# "20260616_153547_43_2562"
# "20260616_172417_10_2528"
# "20260616_171956_62_2528"
# "20260616_171940_20_2528"
# "20260616_172449_95_2528"
# "20260616_171944_89_2528"
# "20260616_172252_62_2528"
# "20260616_172010_70_2528"
# "20260616_172736_57_2528"
# "20260616_172731_87_2528"
# "20260616_172724_83_2528"
# "20260616_172529_85_2528"
# "20260616_171933_16_2528"
# "20260616_172647_29_2528"
# "20260616_172633_21_2528"
# "20260616_171958_97_2528"
# "20260616_172600_35_2528"
# "20260616_172219_77_2528"
# "20260616_172555_66_2528"
# "20260616_172513_42_2528"
# "20260616_172713_10_2528"
# "20260616_171935_50_2528"
# "20260616_171527_64_255c"
# "20260616_171404_65_255c"
# "20260616_172656_67_2528"
# "20260616_172243_24_2528"
# "20260616_171200_99_2510"
# "20260616_141216_11_2544"
# "20260616_172001_32_2528"
# "20260616_153817_30_255c"
# "20260616_145932_93_2514"
# "20260616_172400_68_2528"
# "20260616_172431_18_2528"
# "20260616_171930_81_2528"
# "20260616_172022_44_2528"
# "20260616_172027_13_2528"
# "20260616_171410_06_251a"
# "20260616_171021_06_251a"
# "20260616_172247_93_2528"
# "20260616_172727_18_2528"
# "20260616_154259_27_2571"
# "20260616_184556_02_251a"
# "20260616_171126_27_2530"
# "20260616_184636_55_251a"
# "20260616_172722_49_2528"
# "20260616_184408_93_2530"
# "20260616_172628_51_2528"
# "20260616_171646_10_251a"
# "20260616_184317_66_2530"
# "20260616_172706_06_2528"
# "20260616_172710_75_2528"
# "20260616_172527_50_2528"
# "20260616_184916_64_251a"
# "20260616_172520_46_2528"
# "20260616_172720_14_2528"
# "20260616_105746_40_2549"
# "20260616_172501_69_2528"
# "20260616_172619_13_2528"
# "20260616_172609_74_2528"
# "20260616_172419_45_2528"
# "20260616_171113_75_251a"
# "20260616_184658_20_24e9"
# "20260616_184123_37_24e9"
# "20260616_172017_74_2528"
# "20260616_154347_88_2562"
# "20260616_172109_27_251f"
# "20260616_171819_32_251a"
# "20260616_184529_50_24e9"
# "20260616_155101_43_2562"
# "20260616_153552_82_2530"
# "20260616_172515_77_2528"
# "20260616_172543_93_2528"
# "20260616_170405_56_24e9"
# "20260616_154338_41_2562"
# "20260616_170948_20_2530"
# "20260616_172701_37_2528"
# "20260616_154501_51_2562"
# "20260616_172621_47_2528"
# "20260616_172708_41_2528"
# "20260616_155311_66_2562"
# "20260616_155342_44_2562"
# "20260616_154321_84_2562"
# "20260616_154355_21_2562"
# "20260616_155325_86_2562"
# "20260616_153545_06_2562"
# "20260616_155205_36_2562"
# "20260616_155047_22_2562"
# "20260616_172729_53_2528"
# "20260616_153601_64_2562"
# "20260616_154527_56_2562"
# "20260616_154357_58_2562"
# "20260616_154603_42_2528"
# "20260616_155314_03_2562"
# "20260616_155243_24_2562"
# "20260616_155321_13_2562"
# "20260616_154506_25_2562"
# "20260616_172715_45_2528"
# "20260616_155545_62_2528"
# "20260616_155231_40_2562"
# "20260616_155115_63_2562"
# "20260616_154520_45_2562"
# "20260616_154541_76_2562"
# "20260616_154125_81_2562"
# "20260616_184458_46_24e9"
# "20260616_155359_01_2562"
# "20260616_170930_39_251a"
# "20260616_155604_39_2528"
# "20260616_154045_78_2562"
# "20260616_155306_92_2562"
# "20260616_155415_59_2562"
# "20260616_171738_44_2549"
# "20260616_172209_61_251f"
# "20260616_154407_05_2562"
# "20260616_154121_07_2562"
# "20260616_172734_22_2528"
# "20260616_155021_17_2562"
# "20260616_154319_47_2562"
# "20260616_154144_75_2562"
# "20260616_154921_98_2562"
# "20260616_154544_65_2528"
# "20260616_154336_04_2562"
# "20260616_172534_54_2528"
# "20260616_154343_15_2562"
# "20260616_154118_71_2562"
# "20260616_172522_81_2528"
# "20260616_154444_94_2562"
# "20260616_172211_70_251f"
# "20260616_155134_58_2562"
# "20260616_154945_65_2562"
# "20260616_153622_95_2562"
# "20260616_171937_85_2528"
# "20260616_154924_34_2562"
# "20260616_154222_64_2562"
# "20260616_154136_13_2528"
# "20260616_172445_26_2528"
# "20260616_172159_21_251f"
# "20260616_184527_65_251a"
# "20260616_155132_21_2562"
# "20260616_154310_00_2562"
# "20260616_154225_01_2562"
# "20260616_154203_70_2562"
# "20260616_154116_34_2562"
# "20260616_155226_67_2562"
# "20260616_155129_84_2562"
# "20260616_154213_17_2562"
# "20260616_154210_80_2562"
# "20260616_154201_33_2562"
# "20260616_155344_81_2562"
# "20260616_155042_48_2562"
# "20260616_155337_70_2562"
# "20260616_171947_24_2528"
# "20260616_155403_75_2562"
# "20260616_155254_31_2528"
# "20260616_155028_28_2562"
# "20260616_154409_42_2562"
# "20260616_171826_96_251f"
# "20260616_154248_69_2562"
# "20260616_154230_69_2527"
# "20260616_155345_94_2528"
# "20260616_154059_76_2562"
# "20260616_155127_47_2562"
# "20260616_154055_03_2562"
# "20260616_155347_18_2562"
# "20260616_155323_50_2562"
# "20260616_171950_19_251f"
# "20260616_155221_46_2528"
# "20260616_154936_18_2562"
# "20260616_155524_50_2528"
# "20260616_154229_74_2562"
# "20260616_155023_54_2562"
# "20260616_155233_77_2562"
# "20260616_154456_77_2562"
# "20260616_155341_24_2528"
# "20260616_155148_61_2528"
# "20260616_154938_55_2562"
# "20260616_154929_08_2562"
# "20260616_172550_97_2528"
# "20260616_155125_10_2562"
# "20260616_154328_55_2528"
# "20260616_154113_97_2562"
# "20260616_172433_53_2528"
# "20260616_154933_81_2562"
# "20260616_154220_27_2562"
# "20260616_154003_16_2562"
# "20260616_172504_03_2528"
# "20260616_154137_65_2562"
# "20260616_154406_09_2528"
# "20260616_155616_12_2528"
# "20260616_155200_62_2562"
# "20260616_172215_86_251f"
# "20260616_154149_49_2562"
# "20260616_155634_90_2528"
# "20260616_154950_39_2562"
# "20260616_154452_04_2562"
# "20260616_172247_07_251f"
# "20260616_153554_54_2562"
# "20260616_171937_71_251f"
# "20260616_155625_51_2528"
# "20260616_154601_08_2528"
# "20260616_155351_91_2562"
# "20260616_153639_52_2562"
# "20260616_172207_53_251f"
# "20260616_155406_12_2562"
# "20260616_153606_37_2562"
# "20260616_154408_44_2528"
# "20260616_172155_05_251f"
# "20260616_155533_88_2528"
# "20260616_155237_88_2528"
# "20260616_154953_54_2549"
# "20260616_153948_95_2562"
# "20260616_155522_15_2528"
# "20260616_154154_22_2562"
# "20260616_171839_44_251f"
# "20260616_155247_00_2549"
# "20260616_154957_49_2562"
# "20260616_154648_23_2528"
# "20260616_154048_15_2562"
# "20260616_172226_26_251f"
# "20260616_171833_20_251f"
# "20260616_155037_75_2562"
# "20260616_154513_35_2562"
# "20260616_154931_45_2562"
# "20260616_154140_02_2562"
# "20260616_155120_37_2562"
# "20260616_154300_52_2562"
# "20260616_172138_40_251f"
# "20260616_155602_04_2528"
# "20260616_154041_05_2562"
# "20260616_155627_86_2528"
# "20260616_154817_41_2528"
# "20260616_155245_61_2562"
# "20260616_172021_41_251f"
# "20260616_155405_26_2549"
# "20260616_155155_89_2562"
# "20260616_155144_05_2562"
# "20260616_172324_53_251f"
# "20260616_172301_64_251f"
# "20260616_172015_47_257a"
# "20260616_154647_38_2549"
# "20260616_154345_51_2562"
# "20260616_155113_26_2562"
# "20260616_153953_69_2562"
# "20260616_171910_66_251f"
# "20260616_154356_71_2528"
# "20260616_153703_20_2562"
# "20260616_172337_01_251f"

# %%
# Print the first feature
p(features[0])
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20260616_172548_62_2528",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20260616_172548_62_2528/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20260616_172548_62_2528/thumb"
#   },
#   "_permissions": [],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -100.72027837490471,
#           28.25523928838242
#         ],
#         [
#           -100.36410647786613,
#           28.18965011848578
#         ],
#         [
#           -100.40914416955061,
#           28.001627923523706
#         ],
#         [
#           -100.7643073041518,
#           28.06831216362462
#         ],
#         [
#           -100.72027837490471,
#           28.25523928838242
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20260616_172548_62_2528",
#   "properties": {
#     "acquired": "2026-06-16T17:25:48.626019Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 61,
#     "clear_percent": 11,
#     "cloud_cover": 0.65,
#     "cloud_percent": 65,
#     "ground_control": false,
#     "gsd": 4,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 21,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2026-06-16T21:09:34Z",
#     "publishing_stage": "preview",
#     "quality_category": "test",
#     "satellite_azimuth": 276.8,
#     "satellite_id": "2528",
#     "shadow_percent": 2,
#     "snow_ice_percent": 2,
#     "strip_id": "8850926",
#     "sun_azimuth": 100.7,
#     "sun_elevation": 71.6,
#     "updated": "2026-06-16T21:09:34Z",
#     "view_angle": 5,
#     "visible_confidence_percent": 56,
#     "visible_percent": 35
#   },
#   "type": "Feature"
# }

# %% [markdown]
# What happens when there are A LOT of results?
#
# When the number of matching items exceeds 250, the results are delivered in pages. Let's perform a search query that should return a large number of results:

# %%
# Setup a GeoJSON polygon for our geometry filter
geom = {
    "type": "Polygon",
    "coordinates": [
      [
        [
          -125.29632568359376,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          48.37084770238366
        ]
      ]
    ]
  }

# Setup the geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# %%
# Print the response "_links" property
p(geojson["_links"])
# Out:
# {
#   "_first": "https://api.planet.com/data/v1/searches/24112097233a40438b9efa3905181973/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/24112097233a40438b9efa3905181973/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDI2LTA2LTEyVDAwOjA1OjAwLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjYwNjExXzE5NTEyMl8zM18yNTM0IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/24112097233a40438b9efa3905181973/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
# }

# %%
# Assign the "_links" -> "_next" property (link to next page of results) to a variable 
next_url = geojson["_links"]["_next"]

# Print the link to the next page of results
print(next_url)
# Out:
# https://api.planet.com/data/v1/searches/24112097233a40438b9efa3905181973/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDI2LTA2LTEyVDAwOjA1OjAwLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjYwNjExXzE5NTEyMl8zM18yNTM0IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319

# %% [markdown]
# The page size can be set with a `_page_size` parameter in the request:

# %%
# Send the POST request to the API quick search endpoint with a page size of 9
res = session.post(quick_url, json=request, params={"_page_size" : 9})

# Assign the response to a variable
geojson = res.json()

# Get the number of features present in the response
len(geojson["features"])
# Out:
# 9

# %% [markdown]
# ### Mapping Footprints Example
#
# The [`geojsonio`](https://pypi.python.org/pypi/geojsonio/) module can be used to map GeoJSON files and is therefore compatible with the output from Planet Data API searches.
#
# Make sure you've got the module installed and then let's use it to show our resuls on a map:

# %%
# Assign the url variable to display the geojsonio map
url = geojsonio.display(res.text)

# %% [markdown]
# We can now iterate through the pages of results.

# %%
# Assign the next_url variable to the next page of results from the response (Setup the next page of results)
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %%
# Setup the next page of results
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %% [markdown]
# Cool huh? Now that we know how to search and find items we are interested in, let's try activating and downloading some assets.

# %% [markdown]
# ## Assets & Permissions
#
# Assets may be imagery files, image masks, metadata files or some other file type that might be associated with the item.
#
# The `_permissions` element in each feature contains a list of assets that the user has access to.

# %% [markdown]
# Let's pick the first item out of our search result to work with, and then see what the permissions are for that item:

# %%
# Assign a variable to the search result features (items)
features = geojson["features"]

# Get the first result's feature
feature = features[0]

# Print the ID
p(feature["id"])

# Print the permissions
p(feature["_permissions"])
# Out:
# "20260615_191226_62_2575"
# []

# %% [markdown]
# Each item has an `assets` endpoint in the API that lists all of its assets. Let's get a list of available assets for our item:

# %%
# Get the assets link for the item
assets_url = feature["_links"]["assets"]

# Print the assets link
print(assets_url)
# Out:
# https://api.planet.com/data/v1/item-types/PSScene/items/20260615_191226_62_2575/assets/

# %%
# Send a GET request to the assets url for the item (Get the list of available assets for the item)
res = session.get(assets_url)

# Assign a variable to the response
assets = res.json()

# %%
# Print the asset types that are available
print(assets.keys())
# Out:
# dict_keys([])

# %% [markdown]
# We can see that most items have several assets available. Let's check out the "basic_analytic_4b" asset for this item. This is the 4-band analytic asset for the PSScene item.

# %%
# Assign a variable to the visual asset from the item's assets
basic_analytic4b = assets["basic_analytic_4b"]

# Print the visual asset data
p(basic_analytic4b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Assign a variable to the visual asset from the item's assets
# ----> 2 basic_analytic4b = assets["basic_analytic_4b"]
#       4 # Print the visual asset data
#       5 p(basic_analytic4b)
#
# KeyError: 'basic_analytic_4b'

# %% [markdown]
# ### Activating Assets
#
# Before an asset is available for download, it must be **activated**.
#
# You can activate an asset by sending a _POST_ or _GET_ request to the asset's **"activation link"**.
#
# The activation usually takes a little bit of time, but hey, I'm sure by now you have some ideas on how to automate your workflow. Go robots!

# %%
# Setup the activation url for a particular asset (in this case the basic_analytic_4b asset)
activation_url = basic_analytic4b["_links"]["activate"]

# Send a request to the activation url to activate the item
res = session.get(activation_url)

# Print the response from the activation request
p(res.status_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Setup the activation url for a particular asset (in this case the basic_analytic_4b asset)
# ----> 2 activation_url = basic_analytic4b["_links"]["activate"]
#       4 # Send a request to the activation url to activate the item
#       5 res = session.get(activation_url)
#
# NameError: name 'basic_analytic4b' is not defined

# %% [markdown]
# #### Activation Response Codes
#
# After hitting an activation url, you should get a response code back from the API:
#
# - **`202`** - The request has been accepted and the activation will begin shortly.
# - **`204`** - The asset is already active and no further action is needed.
# - **`401`** - The user does not have permissions to download this file.

# %% [markdown]
# After requesting to actiate an asset, let's do another request to see if the assset's status has changed. This may take some time.

# %%
asset_activated = False

while asset_activated == False:
    # Send a request to the item's assets url
    res = session.get(assets_url)

    # Assign a variable to the item's assets url response
    assets = res.json()

    # Assign a variable to the basic_analytic_4b asset from the response
    visual = assets["basic_analytic_4b"]

    asset_status = basic_analytic4b["status"]
    print(asset_status)
    
    # If asset is already active, we are done
    if asset_status == 'active':
        asset_activated = True
        print("Asset is active and ready to download")

# Print the ps3b_analytic asset data    
p(basic_analytic4b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 11
#       8 assets = res.json()
#      10 # Assign a variable to the basic_analytic_4b asset from the response
# ---> 11 visual = assets["basic_analytic_4b"]
#      13 asset_status = basic_analytic4b["status"]
#      14 print(asset_status)
#
# KeyError: 'basic_analytic_4b'

# %% [markdown]
# #### Activation Status
#
# An asset may have a `status` of `inactive`, `activating` or `active`.
#
# Once an asset is active, the response will contain a `location`. We'll use the `location` to download the asset!
#
# Below, we are polling the API until the item is activated. This may take awhile.

# %% [markdown]
# ### Downloading Assets
#
# The asset's `location` property points asset file for use to download. Are you ready to download the asset? Let's do it!

# %%
# Assign a variable to the visual asset's location endpoint
location_url = basic_analytic4b["location"]

# Print the location endpoint
print(location_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Assign a variable to the visual asset's location endpoint
# ----> 2 location_url = basic_analytic4b["location"]
#       4 # Print the location endpoint
#       5 print(location_url)
#
# NameError: name 'basic_analytic4b' is not defined

# %% [markdown]
# There's the location url! You could click on it to open it in a browser and download the file... but why not let your code do it?
#
# Let's write a small helper function to download asset files:

# %%
# Create a function to download asset files
# Parameters: 
# - url (the location url)
# - filename (the filename to save it as. defaults to whatever the file is called originally)

def pl_download(url, filename=None):
    
    # Send a GET request to the provided location url, using your API Key for authentication
    res = requests.get(url, stream=True, auth=(API_KEY, ""))
    # If no filename argument is given
    if not filename:
        # Construct a filename from the API response
        if "content-disposition" in res.headers:
            filename = res.headers["content-disposition"].split("filename=")[-1].strip("'\"")
        # Construct a filename from the location url
        else:
            filename = url.split("=")[1][:10]
    # Save the file
    with open('output/' + filename, "wb") as f:
        for chunk in res.iter_content(chunk_size=1024):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                f.flush()

    return filename

# %%
# Download the file from an activated asset's location url
pl_download(location_url)

# %% [markdown]
# **High Five!** You should now be downloading your very own GeoTIFF! We can't wait to see what you'll do with it!

# %% [markdown]
# ### Rate Limits
#
# ---
#
# Now that you know how to download assets, you should probably keep some of the API **rate limits** in mind:
#
# - For most endpoints, the rate limit is 10 requests per second, per API key.
# - For activation endpoints, the rate limit is 5 requests per second, per API key.
# - For download endpoints, the rate limit is 15 requests per second, per API key.
#
# If you're writing to code to automate accessing the API, you should account for `429` responses and handle retries after a _backoff period_.

# %% [markdown]
# ## Saved Searches
#
# ---
#
# The `/searches` endpoint lets you created saved searches that can be reused.
#
# To view your saved searches, visit the [`searches/?search_type=saved`](https://api.planet.com/data/v1/searches/?search_type=saved) endpoint.
#
# Finally, let's create a saved search:

# %%
# Setup the saved searches endpoint url
searches_url = "{}/searches".format(URL)

# %%
# Setup the request, specifying a name for the saved search, along with the usual search item_types and filter.
request = {
    "name" : "Vancouver Island",
    "item_types" : item_types,
    "filter" : geometry_filter
}

# Send a POST request to the saved searches endpoint (Create the saved search)
res = session.post(searches_url, json=request)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac",
#     "results": "https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac/results"
#   },
#   "created": "2026-06-16T21:13:10.821201Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "5f3313d319ce4eb6885e4fccc3eaebac",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2026-06-16T21:13:10.821201Z"
# }

# %% [markdown]
# Now that we created a saved search, let's get a list of our saved searches:

# %%
# Send a GET request to the saved searches endpoint with the saved search type parameter (Get saved searches)
res = session.get(searches_url, params={"search_type" : "saved"})

# Assign a variable to the searches property in the saved searches response
searches = res.json()["searches"]
print(searches[0])#['name'])
print(len(searches))

# Loop through the searches
for search in searches:
    # Print the ID, Created Time, and Name for each saved search
    print("id: {} created: {} name: {}".format(search["id"], search["created"], search['name']))
# Out:
# {'__daily_email_enabled': False, '_links': {'_self': 'https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac', 'results': 'https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac/results'}, 'created': '2026-06-16T21:13:10.821201Z', 'filter': {'config': {'coordinates': [[[-125.29632568359376, 48.37084770238366], [-125.29632568359376, 49.335861591104106], [-123.2391357421875, 49.335861591104106], [-123.2391357421875, 48.37084770238366], [-125.29632568359376, 48.37084770238366]]], 'type': 'Polygon'}, 'field_name': 'geometry', 'type': 'GeometryFilter'}, 'id': '5f3313d319ce4eb6885e4fccc3eaebac', 'item_types': ['PSScene'], 'name': 'Vancouver Island', 'search_type': 'saved', 'updated': '2026-06-16T21:13:10.821201Z'}
# 2
# id: 5f3313d319ce4eb6885e4fccc3eaebac created: 2026-06-16T21:13:10.821201Z name: Vancouver Island
# id: 3630323fd78b4a138d40a228a1837ced created: 2026-05-28T04:57:26.674285Z name: bay area

# %% [markdown]
# Ok, now let's check out the results from a particular saved search:

# %%
# Setup the saved search url, using the first saved search in the list
saved_url = "{}/{}".format(searches_url, searches[0]["id"])

# Print the saved search url
p(saved_url)

# Setup the saved search's results url
results_url = "{}/results".format(saved_url)

# Print the saved search's results url
p(results_url)
# Out:
# "https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac"
# "https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac/results"

# %%
# Send a GET request to the saved search url (Get the saved search data)
res = session.get(saved_url)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac",
#     "results": "https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac/results"
#   },
#   "created": "2026-06-16T21:13:10.821201Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "5f3313d319ce4eb6885e4fccc3eaebac",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2026-06-16T21:13:10.821201Z"
# }

# %%
# Send a GET request to the saved search results url (Get the saved search results)
results = session.get(results_url).json()

# Print the number of features in the saved search
print(len(results["features"]))

# Print the first feature in the saved search
print(results["features"][0])
# Out:
# 250
# {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20260615_191347_64_2528', 'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20260615_191347_64_2528/assets/', 'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20260615_191347_64_2528/thumb'}, '_permissions': [], 'assets': ['basic_analytic_4b', 'basic_analytic_4b_rpc', 'basic_analytic_4b_xml', 'basic_analytic_8b', 'basic_analytic_8b_xml', 'basic_udm2', 'ortho_analytic_4b', 'ortho_analytic_4b_sr', 'ortho_analytic_4b_xml', 'ortho_analytic_8b', 'ortho_analytic_8b_sr', 'ortho_analytic_8b_xml', 'ortho_udm2', 'ortho_visual'], 'geometry': {'coordinates': [[[-123.94530089753175, 49.24506482306473], [-124.01000225940226, 49.06514260787045], [-123.55229734861787, 48.993599879867624], [-123.48594060807073, 49.17256304278798], [-123.94530089753175, 49.24506482306473]]], 'type': 'Polygon'}, 'id': '20260615_191347_64_2528', 'properties': {'acquired': '2026-06-15T19:13:47.64411Z', 'anomalous_pixels': 0, 'clear_confidence_percent': 80, 'clear_percent': 3, 'cloud_cover': 0.9, 'cloud_percent': 90, 'ground_control': False, 'gsd': 3.9, 'heavy_haze_percent': 0, 'instrument': 'PSB.SD', 'item_type': 'PSScene', 'light_haze_percent': 0, 'pixel_resolution': 3, 'provider': 'planetscope', 'published': '2026-06-15T23:37:02Z', 'publishing_stage': 'preview', 'quality_category': 'test', 'satellite_azimuth': 103.9, 'satellite_id': '2528', 'shadow_percent': 0, 'snow_ice_percent': 7, 'strip_id': '8849300', 'sun_azimuth': 149.7, 'sun_elevation': 61.7, 'updated': '2026-06-16T09:50:50Z', 'view_angle': 3, 'visible_confidence_percent': 64, 'visible_percent': 10}, 'type': 'Feature'}

# %% [markdown]
# A saved search can also be updated by senidng a **`PUT`** request with a changed search definition back to the API.
#
# Did you know that saved searches can also send you a daily email to alert you to when new items are added to the search resutlts? Oh yeah!

# %%
# Assign a variable to the saved search response
search = res.json()

# Print the saved search
p(search)
# Out:
# {
#   "__daily_email_enabled": true,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac",
#     "results": "https://api.planet.com/data/v1/searches/5f3313d319ce4eb6885e4fccc3eaebac/results"
#   },
#   "created": "2026-06-16T21:13:10.821201Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "type": "GeometryFilter"
#   },
#   "id": "5f3313d319ce4eb6885e4fccc3eaebac",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": "2026-06-16T21:17:52.154948Z",
#   "name": "South Vancouver Island",
#   "search_type": "saved",
#   "updated": "2026-06-16T21:18:09.078681Z"
# }

# %%
# Change the saved search name to "South Vancouver Island"
search["name"] = "South Vancouver Island"

# Set the daily email enabled to true (Get email alerts when new items show up in this search)
search["__daily_email_enabled"] = True

# Send a PUT request to the saved search endpoint (Update the saved search)
res = session.put(saved_url, json=search)

# The response status code
res.status_code
# Out:
# 200

# %% [markdown]
# ## Conclusion
#
# You made it! You should now be able to use the Planet API to find items and assets by searching, get stats and save searches, and activate and download assets using Python code!
#
# Don't forget to visit the [Planet API Reference Docs](https://developers.planet.com/docs/apis/).
