# %%
# TODO

# %%
import pyreadr

# %%
SITE = "Walnut_Gulch_Kendall_Grasslands"
CHUNK_NUMBER = "001"

# %%
result = pyreadr.read_r(f'/projectnb/modislc/users/fache/data/planet/phenology/{SITE}/chunk_phenology_{CHUNK_NUMBER}.rda')

# %%
df = list(result.values())[0]

# %%
print(f"{df.shape=}")
print(f"{df.columns=}")

# %%
df.head()
